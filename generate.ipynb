# %%
import os
import torch
from diffusers import AnimateDiffPipeline, MotionAdapter, EulerDiscreteScheduler
from diffusers.utils import export_to_gif
from huggingface_hub import hf_hub_download
from safetensors.torch import load_file
from model import generate_video, key_frame_img2img

# %%
# Open VPN
os.environ['HTTP_PROXY']="http://Clash:QOAF8Rmd@10.1.0.213:7890"
os.environ['HTTPS_PROXY']="http://Clash:QOAF8Rmd@10.1.0.213:7890"
os.environ['ALL_PROXY']="socks5://Clash:QOAF8Rmd@10.1.0.213:7893"

# %%
generate_video(prompt="A girl dancing on a beach", output_gif="bin/raw.gif", frame_dir="bin/raw_frames")
# Out:
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
# The config attributes {'center_input_sample': False, 'flip_sin_to_cos': True, 'freq_shift': 0, 'mid_block_type': 'UNetMidBlock2DCrossAttn', 'only_cross_attention': False, 'attention_head_dim': 8, 'dual_cross_attention': False, 'class_embed_type': None, 'addition_embed_type': None, 'num_class_embeds': None, 'upcast_attention': False, 'resnet_time_scale_shift': 'default', 'resnet_skip_time_act': False, 'resnet_out_scale_factor': 1.0, 'time_embedding_type': 'positional', 'time_embedding_dim': None, 'time_embedding_act_fn': None, 'timestep_post_act': None, 'time_cond_proj_dim': None, 'conv_in_kernel': 3, 'conv_out_kernel': 3, 'projection_class_embeddings_input_dim': None, 'class_embeddings_concat': False, 'mid_block_only_cross_attention': None, 'cross_attention_norm': None, 'addition_embed_type_num_heads': 64} were passed to UNetMotionModel, but are not expected and will be ignored. Please verify your config.json configuration file.
#   0%|          | 0/8 [00:00<?, ?it/s]

# %%
from preprocess import key_frame_extraction
key_frame_extraction(input_dir="bin/raw_frames", output_dir="bin/key_frames", key_frame_indices=[1, 5, 9, 13])

# %%
key_frame_img2img(input_dir="bin/key_frames",
                      prompt="4k, 1girl, dancing, beach, realistic, clear face, high quality", 
                      negative_prompt="bad anatomy, poorly drawn hands, extra limbs",
                      strength=0.1, guidance_scale=100)
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
from model import ebsynth_frame
ebsynth_frame(input_dir="bin/raw_frames", output_dir="bin/refined_frames", style_dir="bin/refined_key_frames")
# Out:
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/0/frame_1.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/0/frame_2.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/0/frame_3.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/0/frame_4.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/0/frame_5.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/0/frame_6.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/0/frame_7.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/0/frame_8.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/0/frame_9.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/0/frame_10.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/0/frame_11.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/0/frame_12.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/0/frame_13.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/0/frame_14.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/0/frame_15.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/0/frame_16.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/1/frame_1.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/1/frame_2.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/1/frame_3.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/1/frame_4.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/1/frame_5.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/1/frame_6.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/1/frame_7.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/1/frame_8.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/1/frame_9.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/1/frame_10.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/1/frame_11.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/1/frame_12.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/1/frame_13.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/1/frame_14.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/1/frame_15.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/1/frame_16.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/2/frame_1.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/2/frame_2.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/2/frame_3.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/2/frame_4.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/2/frame_5.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/2/frame_6.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/2/frame_7.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/2/frame_8.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/2/frame_9.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/2/frame_10.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/2/frame_11.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/2/frame_12.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/2/frame_13.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/2/frame_14.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/2/frame_15.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/2/frame_16.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/3/frame_1.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/3/frame_2.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/3/frame_3.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/3/frame_4.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/3/frame_5.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/3/frame_6.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/3/frame_7.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/3/frame_8.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/3/frame_9.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/3/frame_10.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/3/frame_11.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/3/frame_12.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/3/frame_13.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/3/frame_14.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/3/frame_15.png
# uniformity: 3500
# patchsize: 5
# pyramidlevels: 7
# searchvoteiters: 6
# patchmatchiters: 4
# stopthreshold: 5
# extrapass3x3: no
# backend: cuda
# result was written to bin/refined_frames/3/frame_16.png
